# %%
import pandas as pd
import numpy as np


df2 = pd.read_hdf('./data/metr-la-backup.h5')
df2.head()

#df = pd.read_csv("./data/small_metr-la.csv")
#df.head()

#filename = './data/testh5.h5'
#df.to_hdf(filename, 'data', mode='w', format='table')
#df2.to_csv(r'test123.csv')
# Out:
#                         773869     767541     767542     717447     717446  \
# 2012-03-01 00:00:00  64.375000  67.625000  67.125000  61.500000  66.875000
# 2012-03-01 00:05:00  62.666667  68.555556  65.444444  62.444444  64.444444
# 2012-03-01 00:10:00  64.000000  63.750000  60.000000  59.000000  66.500000
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000000
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000000
#
#                         717445  773062  767620     737529     717816  ...  \
# 2012-03-01 00:00:00  68.750000  65.125  67.125  59.625000  62.750000  ...
# 2012-03-01 00:05:00  68.111111  65.000  65.000  57.444444  63.333333  ...
# 2012-03-01 00:10:00  66.250000  64.500  64.250  63.875000  65.375000  ...
# 2012-03-01 00:15:00   0.000000   0.000   0.000   0.000000   0.000000  ...
# 2012-03-01 00:20:00   0.000000   0.000   0.000   0.000000   0.000000  ...
#
# ...

# %%
df3 = df2.iloc[70:100,10:25]
df3.head()
# Out:
#                         765604     767471     716339     773906     765273  \
# 2012-03-01 05:50:00  61.222222  65.777778  64.555556  62.333333  56.222222
# 2012-03-01 05:55:00  64.777778  64.555556  65.666667  63.444444  39.777778
# 2012-03-01 06:00:00  64.375000  54.750000  64.625000  66.125000  38.250000
# 2012-03-01 06:05:00  60.285714  64.857143  66.142857  63.142857  24.142857
# 2012-03-01 06:10:00  58.625000  63.375000  64.250000  66.125000  18.125000
#
#                         716331     771667     716337     769953     769402  \
# 2012-03-01 05:50:00  63.888889  35.777778  62.333333  56.111111  63.777778
# 2012-03-01 05:55:00  65.444444  34.333333  61.333333  55.888889  65.555556
# 2012-03-01 06:00:00  64.625000  30.375000  59.125000  62.375000  62.875000
# 2012-03-01 06:05:00  65.714286  35.285714  63.142857  58.000000  61.428571
# 2012-03-01 06:10:00  61.375000  33.375000  59.000000  54.000000  63.375000
#
# ...

# %%
df3.to_csv(r'test30.csv')
filename = './data/test30.h5'
df3.to_hdf(filename, 'data', mode='w', format='table')

# %%
import pickle
df2 = pd.read_pickle("./data/sensor_graph/adj_mx.pkl")
print(type(df2))
print(df2)
df3 = pd.read_pickle("./data/sensor_graph/adj_mx_bay.pkl")
print(type(df3))
